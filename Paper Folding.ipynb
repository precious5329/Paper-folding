# %% [markdown]
# Problem 1

# %%
THICKNESS = 0.00008

folded_thickness = THICKNESS * 2 ** 43

print("Thickness: {} meters".format(folded_thickness))
# Out:
# Thickness: 703687441.77664 meters

# %% [markdown]
# Problem 2

# %%
print("Thickness: {: .2f} kilometers".format(folded_thickness / 1000))
# Out:
# Thickness:  703687.44 kilometers

# %% [markdown]
# Problem 3

# %%
folded_thickness2 = THICKNESS
for i in range (0, 43 ):
  folded_thickness2 *= 2
print("Thickness: {: .2f} kilometers".format(folded_thickness2 / 1000))
# Out:
# Thickness:  703687.44 kilometers

# %% [markdown]
# Problem 4

# %%
import time
start = time.time()

THICKNESS = 0.00008

folded_thickness = THICKNESS * 2 ** 43

print("Thickness: {} meters".format(folded_thickness))

elapsed_time = time.time() - start
print("time : {}[s]".format(elapsed_time))
# Out:
# Thickness: 703687441.77664 meters
# time : 0.00022602081298828125[s]

# %% [markdown]
# Problem 4

# %%
import time
start = time.time()

folded_thickness2 = THICKNESS
for i in range (0, 43 ):
  folded_thickness2 *= 2
print("Thickness: {: .2f} kilometers".format(folded_thickness2 / 1000))

elapsed_time = time.time() - start
print("time : {}[s]".format(elapsed_time))
# Out:
# Thickness:  703687.44 kilometers
# time : 0.0010938644409179688[s]

# %% [markdown]
# Problem 4

# %%
# %%timeit

THICKNESS = 0.00008

folded_thickness = THICKNESS * 2 ** 43

print("Thickness: {} meters".format(folded_thickness))

# %% [markdown]
# Problem 4

# %%
# %%timeit

folded_thickness2 = THICKNESS
for i in range (0, 43 ):
  folded_thickness2 *= 2
print("Thickness: {: .2f} kilometers".format(folded_thickness2 / 1000))

# %% [markdown]
# Problem 5

# %%
folded_thickness_list = []
folded_thickness2 = THICKNESS
for i in range (0, 43):
  folded_thickness2 *= 2
  folded_thickness_list.append(folded_thickness2)

# %% [markdown]
# Problem 6

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(folded_thickness_list)
plt.show()

# %% [markdown]
# Problem 7

# %%
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(folded_thickness_list, color = 'Black')
plt.show()

# %%
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness[m]")
plt.tick_params(labelsize=20)
plt.plot(folded_thickness_list, color = 'Black')
plt.show()
